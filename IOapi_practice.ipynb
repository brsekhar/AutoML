# %% [markdown]
# <a href="https://colab.research.google.com/github/brsekhar/AutoML/blob/master/IOapi_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install TensorFlow GPU
# !pip install tensorflow-gpu==2.12.0
# !pip install keras --upgrade
# !pip install git+https://github.com/keras-team/keras-tuner.git
# !pip install autokeras


# Import necessary modules
import os
import tensorflow as tf

# Configure environment variables
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# Check if GPU is available
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Import other modules
from tensorflow.keras.datasets import mnist
import autokeras as ak

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Create an AutoModel
io_model = ak.AutoModel(inputs=ak.ImageInput(),
                        outputs=ak.ClassificationHead(loss='categorical_crossentropy',
                                                      metrics=[accuracy]),
                        multi_label=False,
                        objective = 'val_loss',
                        tuner = 'random',
                        max_trials = 3)

# Train the model
io_model.fit(x_train, y_train, epochs=3)

# Evaluate the model
io_model.evaluate(x_test, y_test)
# Out:
# ...
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# ...
#   Cloning https://github.com/keras-team/keras-tuner.git to /tmp/pip-req-build-sr_w7fmb
#   Running command git clone --filter=blob:none --quiet https://github.com/keras-team/keras-tuner.git /tmp/pip-req-build-sr_w7fmb
#   Resolved https://github.com/keras-team/keras-tuner.git to commit 8aa8dc2971d2858823dd21c5492f2f1478654eb0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...
